# %%
import pyarrow.parquet as pq
import pandas as pd
import os

# %%
path = os.path.join('datas', 'ebnerd_demo','train', 'behaviors.parquet')
#print(path)
behaviors = pq.read_table(path).to_pandas()
behaviors.isna().sum()/behaviors.shape[0]
behaviors.dropna(inplace=True)
behaviors
# Out:
#        impression_id  article_id     impression_time  read_time  \
# 283          5068020   9777693.0 2023-05-23 13:44:31       88.0
# 284          5068022   9777565.0 2023-05-23 13:35:43      106.0
# 286          5068027   9777529.0 2023-05-23 13:41:05      141.0
# 3101        68748396   9778328.0 2023-05-23 20:23:08      220.0
# 4436       102365531   9773356.0 2023-05-20 09:42:19       60.0
# 4437       102365534   9773356.0 2023-05-20 09:00:39       29.0
# 5664       133495916   9774764.0 2023-05-21 15:28:11       23.0
# 5666       133495919   9774764.0 2023-05-21 15:26:28       72.0
# 6696       156742078   9771042.0 2023-05-18 08:23:58       39.0
# 6697       156742081   9770729.0 2023-05-18 08:22:57       60.0
# 7497       178013524   9774376.0 2023-05-21 07:38:44       60.0
# 13187      317174181   9772284.0 2023-05-19 09:45:30       16.0
# 13966      334071765   9774032.0 2023-05-21 10:35:19       27.0
# 15441      369391822   9776508.0 2023-05-22 21:24:30       26.0
# ...

# %%
path = os.path.join('datas', 'ebnerd_demo','train', 'history.parquet')
#print(path)
history = pq.read_table(path).to_pandas()
history
#legs.describe()
# Out:
#       user_id                              impression_time_fixed  \
# 0       13538  [2023-04-27T10:17:43.000000, 2023-04-27T10:18:...
# 1       58608  [2023-04-27T18:48:09.000000, 2023-04-27T18:48:...
# 2       95507  [2023-04-27T15:20:28.000000, 2023-04-27T15:20:...
# 3      106588  [2023-04-27T08:29:09.000000, 2023-04-27T08:29:...
# 4      617963  [2023-04-27T14:42:25.000000, 2023-04-27T14:43:...
# ...       ...                                                ...
# 1585  1122370  [2023-05-09T06:50:19.000000, 2023-05-09T06:51:...
# 1586  1718049  [2023-05-17T05:04:36.000000, 2023-05-17T05:04:...
# 1587  1178033  [2023-04-29T19:36:47.000000, 2023-04-29T19:37:...
# 1588   395912  [2023-05-12T05:12:34.000000, 2023-05-12T05:12:...
# 1589  2539047  [2023-05-09T10:37:17.000000, 2023-05-09T10:37:...
#
#                                 scroll_percentage_fixed  \
# 0     [100.0, 35.0, 100.0, 24.0, 100.0, 23.0, 100.0,...
# 1     [37.0, 61.0, 100.0, 100.0, 55.0, 100.0, 100.0,...
# ...

# %%
path = os.path.join('datas', 'ebnerd_demo', 'articles.parquet')
#print(path)
articles = pq.read_table(path).to_pandas()
articles.isna().sum()/len(legs)
len(articles.loc[:,'article_id'].unique())
#legs.describe()
# Out:
# 11777

# %%
len(behaviors.loc[:,'article_id'].unique())
# Out:
# 923
