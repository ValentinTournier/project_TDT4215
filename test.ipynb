# %%
import pyarrow.parquet as pq
import pandas as pd
import os

# %%
path = os.path.join('iweech', 'iw-datalake', d, 'legs',
                    "user_id={}".format(user),
                    "bike_id={}".format(bike),
                    "month={}".format(month)
                    )
#print(path)
legs = pq.read_table(path).to_pandas()
